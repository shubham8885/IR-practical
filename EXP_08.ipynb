# %% [markdown]
# Name:Suraj Gude ROll NO:19141246 IR exp-08 Write a program to implement web crawling using BFS/DFS.

# %%
# Import libraries
from urllib.request import urljoin
from bs4 import BeautifulSoup
import requests
from urllib.request import urlparse


# Set for storing urls with same domain
links_intern = set()
input_url = "https://internshala.com/student/dashboard"
depth = 1

# Set for storing urls with different domain
links_extern = set()


# Method for crawling a url at next level
def level_crawler(input_url):
 temp_urls = set()
 current_url_domain = urlparse(input_url).netloc

 # Creates beautiful soup object to extract html tags
 beautiful_soup_object = BeautifulSoup(
  requests.get(input_url).content, "lxml")

 # Access all anchor tags from input
 # url page and divide them into internal
 # and external categories
 for anchor in beautiful_soup_object.findAll("a"):
  href = anchor.attrs.get("href")
  if(href != "" or href != None):
   href = urljoin(input_url, href)
   href_parsed = urlparse(href)
   href = href_parsed.scheme
   href += "://"
   href += href_parsed.netloc
   href += href_parsed.path
   final_parsed_href = urlparse(href)
   is_valid = bool(final_parsed_href.scheme) and bool(
    final_parsed_href.netloc)
   if is_valid:
    if current_url_domain not in href and href not in links_extern:
     print("Extern - {}".format(href))
     links_extern.add(href)
    if current_url_domain in href and href not in links_intern:
     print("Intern - {}".format(href))
     links_intern.add(href)
     temp_urls.add(href)
 return temp_urls


if(depth == 0):
 print("Intern - {}".format(input_url))

elif(depth == 1):
 level_crawler(input_url)

else:
 # We have used a BFS approach
 # considering the structure as
 # a tree. It uses a queue based
 # approach to traverse
 # links upto a particular depth.
 queue = []
 queue.append(input_url)
 for j in range(depth):
  for count in range(len(queue)):
   url = queue.pop(0)
   urls = level_crawler(url)
   for i in urls:
    queue.append(i)
# Out:
# Intern - https://internshala.com/student/dashboard
# Intern - https://internshala.com/internships
# Intern - https://trainings.internshala.com/
# Intern - https://internshala.com/internships/work-from-home-internships
# Intern - https://internshala.com/jobs
# Intern - https://internshala.com/contact
# Intern - https://internshala.com/registration/student
# Intern - https://internshala.com/registration/employer
# Intern - https://internshala.com/login/user
# Intern - https://internshala.com/
# Intern - https://internshala.com/internships/internship-in-bangalore
# Intern - https://internshala.com/internships/internship-in-delhi
# Intern - https://internshala.com/internships/internship-in-hyderabad
# Intern - https://internshala.com/internships/internship-in-mumbai
# Intern - https://internshala.com/internships/internship-in-chennai
# Intern - https://internshala.com/internships/internship-in-pune
# Intern - https://internshala.com/internships/internship-in-kolkata
# Intern - https://internshala.com/internships/internship-in-jaipur
# Intern - https://internshala.com/internships/international-internship
# Intern - https://internshala.com/internships/
# Intern - https://internshala.com/internships/computer-science-internship
# Intern - https://internshala.com/internships/marketing%2Fsales-internship
# Intern - https://internshala.com/internships/finance-internship
# Intern - https://internshala.com/internships/graphic-design-internship
# Intern - https://internshala.com/internships/architecture-internship
# Intern - https://internshala.com/internships/mechanical-internship
# Intern - https://internshala.com/internships/hr-internship
# Intern - https://internshala.com/internships/digital-marketing-internship
# Intern - https://internshala.com/internships/law-internship
# Intern - https://internshala.com/internships/electronics-internship
# Intern - https://internshala.com/internships/content-writing-internship
# Intern - https://internshala.com/internships/civil-internship
# Intern - https://internshala.com/internships/campus-ambassador-internship
