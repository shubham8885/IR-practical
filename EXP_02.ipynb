# %% [markdown]
# Name:Suraj Gude ROll NO:19141246 IR exp-02 Perform the experiment to demonstrate Lemmatization and Stemming on given text.

# %%
# import these modules
#For Lemmatization
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()
print("Suraj Gude" )
print("rocks :", lemmatizer.lemmatize("Dhiraj"))
print("corpora :", lemmatizer.lemmatize("Gude"))

# a denotes adjective in "pos"
print("better :", lemmatizer.lemmatize("better", pos="a"))
# For Stemming
# import these modules
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()

# choose some words to be stemmed
words = ["game", "games", "gameing", "gamers"]

for w in words:
    print(w, " : ", ps.stem(w))
# Out:
# Suraj Gude
# rocks : Dhiraj
# corpora : Gude
# better : good
# game  :  game
# games  :  game
# gameing  :  game
# gamers  :  gamer
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
